# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # it helps us to split our data into training data and test data
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score # performance check krne ke liye model ka

# %%
credit_card_data=pd.read_csv('creditcard.csv')
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data=pd.read_csv('creditcard.csv')
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
mid=len(credit_card_data)//2
credit_card_data.iloc[:mid].to_csv('part1.csv', index=False)
credit_card_data.iloc[mid:].to_csv('part2.csv', index=False)

# %%
# "ye v1 se lekar v28 tk features h particular transaction ka, credit card details bahut sensitive hota isiliye wo nhi diya hua h jo dataset banaya h usne
# PCA ke madat se sare features ko numerical form me convert kr diya h, hum isi a use krke apna analysis krege
# amount dollar me diya h
# class bta rha h ke jo transaction hua h wo sahi transaction hua h ya nhi 0 mtlb ha or 1 mtlb na

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts() # distribution of datapoint
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# this dataset is very unbalnced because we have 2 target variables and more than 99% data belongs to 1 particular class
# so, we cannot train our model with this data because it can't recognise fraud transaction because we have very less data points for this case

# %%
# separating variable for analysis
legit=credit_card_data[credit_card_data.Class == 0]
fraud=credit_card_data[credit_card_data.Class == 1]

# %%
print(fraud.shape)
print(legit.shape)
# Out:
# (492, 31)
# (284315, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# mean fraud ka jayada h legit transaction se
# aab dono class ko compare karege

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# so there is a huge difference between mean of normal transaction and fraudulent transaction
# build a sample dataset containing similar distribution of normal and fraudulent transaction

# %%
legit_sample=legit.sample(n=492)
new_dataset=pd.concat([legit_sample,fraud],axis =0) # axis =0 means data is added row vise if axis=1value is added column vise

# %%
new_dataset
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 90127    62873.0  0.925269  0.277297  0.359685  2.794218  0.020328  0.488582
# 14208    25248.0  1.157699 -0.376094  0.827239 -0.560334 -1.173033 -0.965975
# 209346  137520.0  1.684112 -1.055121 -0.884754  0.924333  1.246386  4.671238
# 4226      3752.0  0.844459 -1.333997  0.392835 -0.412436 -1.197115 -0.153743
# 204040  135084.0 -0.843449  0.371714  0.074943 -1.774453  2.410617  4.029540
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94707.369919 -0.043550 -0.185447 -0.097336  0.003723 -0.027787
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.024501 -0.004132 -0.021205  0.002893  ...  0.034622 -0.005436
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.035479  0.015971  0.021486  0.043739  0.006437 -0.015770 -0.025348
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      107.254878
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# spiliting data into features and target
# feature jo h ke v1 se 28 tk or time wagera h or target me class h 0 ya 1
x = new_dataset.drop(columns='Class' ,axis=1)
y=new_dataset['Class']

# %%
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 90127    62873.0  0.925269  0.277297  0.359685  2.794218  0.020328  0.488582
# 14208    25248.0  1.157699 -0.376094  0.827239 -0.560334 -1.173033 -0.965975
# 209346  137520.0  1.684112 -1.055121 -0.884754  0.924333  1.246386  4.671238
# 4226      3752.0  0.844459 -1.333997  0.392835 -0.412436 -1.197115 -0.153743
# 204040  135084.0 -0.843449  0.371714  0.074943 -1.774453  2.410617  4.029540
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, stratify=y, random_state=2)

# %%
# x_train contains all the value of this 30 column 
# and the corresponding label which is obtain from y will be stored in y train
# 80% of data is stored in x train and corresponding label should be stored in y train
# 20% data is stored in x test and the corresponding label should be stored in y test
# if we don't mention stratify=y so distribution of 0 and 1 can be very differnt in training data and testing data
# so, if we write stratify=y there will evenly distributed 2 classes in x test and y test
# random_state=2 it means how do you want to split your data, it is nothing just to reproduce the code as it is

# %%
print(x_train.shape, x_test.shape)
# Out:
# (787, 30) (197, 30)

# %%
model=LogisticRegression(solver='liblinear',max_iter=1000)
# training the logistics regression model with training data
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
# max_iter=1000) means maximum number of iteration this solver will perform during traning
# LIBLINEAR is a linear classifier for data with millions of features 
# fit - this will fit our data to logistics model

# %%
# now checking the performance of the model by checking the accuracy based on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction, y_train)

# %%
# x_train_prediction me jo x-train predict kiya wo sare labels ka value h
# uske baad x_train_predictionke value ko original value se compare kr liya gya
training_data_accuracy
# Out:
# 0.940279542566709

# %%
# calculating accuracy of x_test
x_test_prediction = model.predict(x_test)
testing_data_accuracy=accuracy_score(x_test_prediction, y_test)
testing_data_accuracy
# Out:
# 0.9543147208121827
